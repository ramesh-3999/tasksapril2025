# %% [markdown]
# **Import pandas**

# %%
import pandas as pd

# %%
#Import data set

# %%
ola_booking=pd.read_csv("ola.csv")

# %%
#first look at dataset

# %%
ola_booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   datetime       10886 non-null  object
#  1   season         10886 non-null  int64
#  2   weather        10886 non-null  int64
#  3   temp           10886 non-null  float64
#  4   ola_humidity   10886 non-null  float64
#  5   ola_windspeed  10886 non-null  float64
#  6   casual         10884 non-null  object
#  7   registered     10884 non-null  float64
#  8   count          10886 non-null  int64
#  9   un_name        11 non-null     object
#  10  company        41 non-null     object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 935.6+ KB

# %%
ola_booking.describe()
# Out:
#              season       weather          temp  ola_humidity  ola_windspeed  \
# count  10886.000000  10886.000000  10886.000000  10886.000000   10886.000000
# mean       2.493937      2.491916     20.137973     59.946072      24.960981
# std        1.120531      1.123139      8.696625     22.987200      14.424684
# min        1.000000      1.000000      5.000000     20.000000       0.000000
# 25%        1.000000      1.000000     12.630000     40.040000      12.522500
# 50%        2.000000      2.000000     20.190000     59.970000      25.000000
# 75%        3.000000      4.000000     27.707500     79.620000      37.427500
# max        4.000000      4.000000     35.000000     99.980000      49.990000
#
#          registered         count
# count  10884.000000  10886.000000
# mean      99.565693    124.068988
# std       57.536755     59.449265
# min        0.000000      0.000000
# 25%       50.000000     74.000000
# 50%      100.000000    124.000000
# ...

# %%
ola_booking.head(50)
# Out:
#             datetime  season  weather   temp  ola_humidity  ola_windspeed  \
# 0   01-01-2011 00:00       3        2   6.66         76.62           9.57
# 1   01-01-2011 01:00       4        3  13.54         55.91           4.01
# 2   01-01-2011 02:00       1        3  29.58         20.97          33.61
# 3   01-01-2011 03:00       3        1   7.40         61.64          15.85
# 4   01-01-2011 04:00       3        4  30.66         98.71          11.47
# ..               ...     ...      ...    ...           ...            ...
# 45  02-01-2011 21:00       4        1  16.15         67.60          19.91
# 46  02-01-2011 22:00       4        4  11.27         99.89           7.54
# 47  02-01-2011 23:00       3        1  28.25         95.56          23.07
# 48  03-01-2011 00:00       2        4  17.99         20.21          47.55
# 49  03-01-2011 01:00       2        2  10.76         83.63          40.08
#
#    casual  registered  count un_name company
# ...

# %%
ola_booking.columns
# Out:
# Index(['datetime', 'season', 'weather', 'temp', 'ola_humidity',
#        'ola_windspeed', 'casual', 'registered', 'count', 'un_name', 'company'],
#       dtype='object')

# %%
ola_booking.drop(columns=['un_name'],inplace=True)

# %%
ola_booking
# Out:
#                datetime  season  weather   temp  ola_humidity  ola_windspeed  \
# 0      01-01-2011 00:00       3        2   6.66         76.62           9.57
# 1      01-01-2011 01:00       4        3  13.54         55.91           4.01
# 2      01-01-2011 02:00       1        3  29.58         20.97          33.61
# 3      01-01-2011 03:00       3        1   7.40         61.64          15.85
# 4      01-01-2011 04:00       3        4  30.66         98.71          11.47
# ...                 ...     ...      ...    ...           ...            ...
# 10881  29-03-2012 09:00       4        4  28.24         67.88          47.74
# 10882  29-03-2012 10:00       3        4  17.13         22.36          15.27
# 10883  29-03-2012 11:00       3        3  19.83         99.17          30.35
# 10884  29-03-2012 12:00       2        4  15.70         77.30          40.16
# 10885  29-03-2012 13:00       2        3  34.57         54.03           6.64
#
#       casual  registered  count company
# ...

# %%
ola_booking.rename({'ola_humidity':'humidity','ola_windspeed':'windspeed'},axis=1,inplace=True)
ola_booking.head(20)
# Out:
#             datetime  season  weather   temp  humidity  windspeed casual  \
# 0   01-01-2011 00:00       3        2   6.66     76.62       9.57      5
# 1   01-01-2011 01:00       4        3  13.54     55.91       4.01     36
# 2   01-01-2011 02:00       1        3  29.58     20.97      33.61     34
# 3   01-01-2011 03:00       3        1   7.40     61.64      15.85      6
# 4   01-01-2011 04:00       3        4  30.66     98.71      11.47     14
# ..               ...     ...      ...    ...       ...        ...    ...
# 15  01-01-2011 15:00       1        4  22.66     63.12      10.81     41
# 16  01-01-2011 16:00       4        1  28.70     76.56      19.58    NaN
# 17  01-01-2011 17:00       4        4  24.69     53.51      41.36     42
# 18  01-01-2011 18:00       4        2  23.26     73.54       7.42      0
# 19  01-01-2011 19:00       3        3  17.35     29.73      21.73     19
#
#     registered  count company
# 0        128.0    133     abc
# ...

# %%
#Find Nan values

# %%
ola_booking.isnull().sum()#To get the count of nulls by columns wise
ola_booking.isnull().sum()*100/len(ola_booking)#To get the % count of nulls by columns wise
# Out:
# datetime       0.000000
# season         0.000000
# weather        0.000000
# temp           0.000000
# humidity       0.000000
# windspeed      0.000000
# casual         0.018372
# registered     0.018372
# count          0.000000
# company       99.623369
# dtype: float64

# %%
ola_booking['casual'].unique()
value_counts = ola_booking['casual'].value_counts()
#more_than_once = value_counts[value_counts > 1]
sorted_counts = value_counts.sort_values(ascending=True)
sorted_counts
# Out:
# casual
# 40?"      1
# 46      179
# 32      190
# 47      196
# 12      196
#        ...
# 29      239
# 48      240
# 24      245
# 44      246
# 35      247
# Name: count, Length: 51, dtype: int64

# %%
ola_booking[ola_booking['casual']==10]#We are not getting any O/P because it consideres 5 as string 5' but we given as int
# Out:
# Empty DataFrame
# Columns: [datetime, season, weather, temp, humidity, windspeed, casual, registered, count, company]
# Index: []

# %%
print(ola_booking['casual'].dtype)#Lets see the datatype of the column
# Out:
# object

# %%
#Replacing the null values of the column with appropriate default value based on analysis.
ola_booking['casual'].fillna({'casual':-1}, inplace=True)#This means we a re replacing the null values in calual column with -1
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10888\3411311185.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ola_booking['casual'].fillna({'casual':-1}, inplace=True)#This means we a re replacing the null values in calual column with -1

# %%
ola_booking[ola_booking['casual'].isnull()]
# Out:
#             datetime  season  weather   temp  humidity  windspeed casual  \
# 16  01-01-2011 16:00       4        1  28.70     76.56      19.58    NaN
# 26  02-01-2011 02:00       2        3  11.07     76.17      37.93    NaN
#
#     registered  count company
# 16       124.0    168       a
# 26        70.0    104       f

# %%
ola_booking.isnull().sum()*100/len(ola_booking)#To get the % count of nulls by columns wise
# Out:
# datetime       0.000000
# season         0.000000
# weather        0.000000
# temp           0.000000
# humidity       0.000000
# windspeed      0.000000
# casual         0.018372
# registered     0.018372
# count          0.000000
# company       99.623369
# dtype: float64

# %%
ola_booking[ola_booking['company'].notnull()]#placed some junk company name ,We will drop that column
# Out:
#             datetime  season  weather   temp  humidity  windspeed casual  \
# 0   01-01-2011 00:00       3        2   6.66     76.62       9.57      5
# 1   01-01-2011 01:00       4        3  13.54     55.91       4.01     36
# 3   01-01-2011 03:00       3        1   7.40     61.64      15.85      6
# 4   01-01-2011 04:00       3        4  30.66     98.71      11.47     14
# 5   01-01-2011 05:00       4        1   7.76     61.84      19.00     20
# ..               ...     ...      ...    ...       ...        ...    ...
# 39  02-01-2011 15:00       3        4  11.44     38.18      28.66     26
# 40  02-01-2011 16:00       3        2  30.03     46.62      18.09     16
# 41  02-01-2011 17:00       3        3  17.61     22.53      17.54     31
# 42  02-01-2011 18:00       2        3  22.31     68.63      34.39   40?"
# 43  02-01-2011 19:00       4        4  31.19     65.50      23.18     29
#
#     registered  count company
# 0        128.0    133     abc
# ...

# %%
ola_booking.drop(columns=['company'],inplace=True)

# %%
ola_booking
# Out:
#                datetime  season  weather   temp  humidity  windspeed casual  \
# 0      01-01-2011 00:00       3        2   6.66     76.62       9.57      5
# 1      01-01-2011 01:00       4        3  13.54     55.91       4.01     36
# 2      01-01-2011 02:00       1        3  29.58     20.97      33.61     34
# 3      01-01-2011 03:00       3        1   7.40     61.64      15.85      6
# 4      01-01-2011 04:00       3        4  30.66     98.71      11.47     14
# ...                 ...     ...      ...    ...       ...        ...    ...
# 10881  29-03-2012 09:00       4        4  28.24     67.88      47.74     48
# 10882  29-03-2012 10:00       3        4  17.13     22.36      15.27      4
# 10883  29-03-2012 11:00       3        3  19.83     99.17      30.35     38
# 10884  29-03-2012 12:00       2        4  15.70     77.30      40.16     36
# 10885  29-03-2012 13:00       2        3  34.57     54.03       6.64     39
#
#        registered  count
# 0           128.0    133
# ...

# %%
ola_booking.isnull().sum()*100/len(ola_booking)#To get the % count of nulls by columns wise
# Out:
# datetime      0.000000
# season        0.000000
# weather       0.000000
# temp          0.000000
# humidity      0.000000
# windspeed     0.000000
# casual        0.018372
# registered    0.018372
# count         0.000000
# dtype: float64

# %%
ola_booking[ola_booking['registered'].isna()]
# Out:
#             datetime  season  weather   temp  humidity  windspeed casual  \
# 32  02-01-2011 08:00       4        3  23.28     32.89      21.09     47
# 36  02-01-2011 12:00       4        1  14.74     31.79      33.32      8
#
#     registered  count
# 32         NaN     75
# 36         NaN     24

# %%
ola_booking['registered'].fillna(-1,inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10888\2877457839.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ola_booking['registered'].fillna(-1,inplace=True)

# %%
ola_booking.isnull().sum()*100/len(ola_booking)
# Out:
# datetime      0.000000
# season        0.000000
# weather       0.000000
# temp          0.000000
# humidity      0.000000
# windspeed     0.000000
# casual        0.018372
# registered    0.000000
# count         0.000000
# dtype: float64

# %%
#so data handled ,Now lets see the datatypes
pd.set_option('display.max_rows', 10)
ola_booking.dtypes
#Observe the the column name and corresponsinf datype matches or not with general sence .
#We can observe that registered can be boolean value ,So we can change dtype of registered
# Out:
# datetime       object
# season          int64
# weather         int64
# temp          float64
# humidity      float64
# windspeed     float64
# casual         object
# registered    float64
# count           int64
# dtype: object

# %%
ola_booking=ola_booking.astype({'registered':'int'})

# %%
ola_booking.dtypes
# Out:
# datetime       object
# season          int64
# weather         int64
# temp          float64
# humidity      float64
# windspeed     float64
# casual         object
# registered      int64
# count           int64
# dtype: object

# %%
ola_booking
# Out:
#                datetime  season  weather   temp  humidity  windspeed casual  \
# 0      01-01-2011 00:00       3        2   6.66     76.62       9.57      5
# 1      01-01-2011 01:00       4        3  13.54     55.91       4.01     36
# 2      01-01-2011 02:00       1        3  29.58     20.97      33.61     34
# 3      01-01-2011 03:00       3        1   7.40     61.64      15.85      6
# 4      01-01-2011 04:00       3        4  30.66     98.71      11.47     14
# ...                 ...     ...      ...    ...       ...        ...    ...
# 10881  29-03-2012 09:00       4        4  28.24     67.88      47.74     48
# 10882  29-03-2012 10:00       3        4  17.13     22.36      15.27      4
# 10883  29-03-2012 11:00       3        3  19.83     99.17      30.35     38
# 10884  29-03-2012 12:00       2        4  15.70     77.30      40.16     36
# 10885  29-03-2012 13:00       2        3  34.57     54.03       6.64     39
#
#        registered  count
# 0             128    133
# ...

# %%
ola_booking['temp'].unique()
ola_booking['temp'].describe()
bins=[0,10,20,30,40]
lables=['0-10','11-20','21-30','31-40']
ola_booking['temp_binned']=pd.cut(ola_booking['temp'],bins=bins,labels=lables)#This pd.cut function is usedto creste the groups based on range 
ola_booking[['temp','temp_binned']]
# Out:
#         temp temp_binned
# 0       6.66        0-10
# 1      13.54       11-20
# 2      29.58       21-30
# 3       7.40        0-10
# 4      30.66       31-40
# ...      ...         ...
# 10881  28.24       21-30
# 10882  17.13       11-20
# 10883  19.83       11-20
# 10884  15.70       11-20
# 10885  34.57       31-40
#
# [10886 rows x 2 columns]

# %%
ola_booking
# Out:
#                datetime  season  weather   temp  humidity  windspeed casual  \
# 0      01-01-2011 00:00       3        2   6.66     76.62       9.57      5
# 1      01-01-2011 01:00       4        3  13.54     55.91       4.01     36
# 2      01-01-2011 02:00       1        3  29.58     20.97      33.61     34
# 3      01-01-2011 03:00       3        1   7.40     61.64      15.85      6
# 4      01-01-2011 04:00       3        4  30.66     98.71      11.47     14
# ...                 ...     ...      ...    ...       ...        ...    ...
# 10881  29-03-2012 09:00       4        4  28.24     67.88      47.74     48
# 10882  29-03-2012 10:00       3        4  17.13     22.36      15.27      4
# 10883  29-03-2012 11:00       3        3  19.83     99.17      30.35     38
# 10884  29-03-2012 12:00       2        4  15.70     77.30      40.16     36
# 10885  29-03-2012 13:00       2        3  34.57     54.03       6.64     39
#
#        registered  count temp_binned
# ...

# %%
ola_booking['R_date']=ola_booking['datetime'].str.split(' ', expand=True)[0]
ola_booking['R_time']=ola_booking['datetime'].str.split(' ', expand=True)[1]
#ola_booking.head()
#We need those 2 columns in 1st and 2nd place 
column_to_move=ola_booking.pop('R_date')
ola_booking.insert(1,'R_date',column_to_move)

# %%
ola_booking.head()
column_to_move=ola_booking.pop('R_time')
ola_booking.insert(2,'R_time',column_to_move)

# %%
ola_booking.drop(columns=['datetime'],inplace=True)
ola_booking
# Out:
#            R_date R_time  season  weather   temp  humidity  windspeed casual  \
# 0      01-01-2011  00:00       3        2   6.66     76.62       9.57      5
# 1      01-01-2011  01:00       4        3  13.54     55.91       4.01     36
# 2      01-01-2011  02:00       1        3  29.58     20.97      33.61     34
# 3      01-01-2011  03:00       3        1   7.40     61.64      15.85      6
# 4      01-01-2011  04:00       3        4  30.66     98.71      11.47     14
# ...           ...    ...     ...      ...    ...       ...        ...    ...
# 10881  29-03-2012  09:00       4        4  28.24     67.88      47.74     48
# 10882  29-03-2012  10:00       3        4  17.13     22.36      15.27      4
# 10883  29-03-2012  11:00       3        3  19.83     99.17      30.35     38
# 10884  29-03-2012  12:00       2        4  15.70     77.30      40.16     36
# 10885  29-03-2012  13:00       2        3  34.57     54.03       6.64     39
#
#        registered  count temp_binned
# ...

# %%
ola_booking['casual'].unique()
# Out:
# array(['5', '36', '34', '6', '14', '20', '37', '35', '22', '28', '12',
#        '4', '46', '38', '41', nan, '42', '0', '19', '39', '44', '33',
#        '49', '47', '26', '8', '16', '31', '40?"', '29', '27', '2', '1',
#        '15', '43', '11', '25', '48', '23', '17', '7', '30', '40', '21',
#        '32', '3', '18', '9', '13', '10', '45', '24'], dtype=object)

# %%
#Above we have one value 40?" .We cleaned using the regex
ola_booking['casual']=ola_booking['casual'].replace(r"[?\"]",'',regex=True)
ola_booking['casual'].unique()
# Out:
# array(['5', '36', '34', '6', '14', '20', '37', '35', '22', '28', '12',
#        '4', '46', '38', '41', nan, '42', '0', '19', '39', '44', '33',
#        '49', '47', '26', '8', '16', '31', '40', '29', '27', '2', '1',
#        '15', '43', '11', '25', '48', '23', '17', '7', '30', '21', '32',
#        '3', '18', '9', '13', '10', '45', '24'], dtype=object)

# %%
#check for duplicate records
ola_booking.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10881    False
# 10882    False
# 10883    False
# 10884    False
# 10885    False
# Length: 10886, dtype: bool

# %%
#final check 
ola_booking #Could see company with nill data
# Out:
#            R_date R_time  season  weather   temp  humidity  windspeed casual  \
# 0      01-01-2011  00:00       3        2   6.66     76.62       9.57      5
# 1      01-01-2011  01:00       4        3  13.54     55.91       4.01     36
# 2      01-01-2011  02:00       1        3  29.58     20.97      33.61     34
# 3      01-01-2011  03:00       3        1   7.40     61.64      15.85      6
# 4      01-01-2011  04:00       3        4  30.66     98.71      11.47     14
# ...           ...    ...     ...      ...    ...       ...        ...    ...
# 10881  29-03-2012  09:00       4        4  28.24     67.88      47.74     48
# 10882  29-03-2012  10:00       3        4  17.13     22.36      15.27      4
# 10883  29-03-2012  11:00       3        3  19.83     99.17      30.35     38
# 10884  29-03-2012  12:00       2        4  15.70     77.30      40.16     36
# 10885  29-03-2012  13:00       2        3  34.57     54.03       6.64     39
#
#        registered  count temp_binned
# ...

# %%
ola_booking
# Out:
#            R_date R_time  season  weather   temp  humidity  windspeed casual  \
# 0      01-01-2011  00:00       3        2   6.66     76.62       9.57      5
# 1      01-01-2011  01:00       4        3  13.54     55.91       4.01     36
# 2      01-01-2011  02:00       1        3  29.58     20.97      33.61     34
# 3      01-01-2011  03:00       3        1   7.40     61.64      15.85      6
# 4      01-01-2011  04:00       3        4  30.66     98.71      11.47     14
# ...           ...    ...     ...      ...    ...       ...        ...    ...
# 10881  29-03-2012  09:00       4        4  28.24     67.88      47.74     48
# 10882  29-03-2012  10:00       3        4  17.13     22.36      15.27      4
# 10883  29-03-2012  11:00       3        3  19.83     99.17      30.35     38
# 10884  29-03-2012  12:00       2        4  15.70     77.30      40.16     36
# 10885  29-03-2012  13:00       2        3  34.57     54.03       6.64     39
#
#        registered  count temp_binned
# ...
